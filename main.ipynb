# %%
import os
HOME = os.getcwd()

print(HOME)
# Out:
# c:\Users\Prajwal\Desktop\check

# %%
IMAGE_DIR_PATH = f"{HOME}/images"

# %%
DATA_YAML_PATH = f"{HOME}/dataset_cond/data.yaml"

# %%
from autodistill_yolov8 import YOLOv8

# Load YOLOv8 model
target_model = YOLOv8("yolov8n.pt")

target_model.train(DATA_YAML_PATH, epochs=50, device=[0])
# Out:
# New https://pypi.org/project/ultralytics/8.3.13 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.81  Python-3.12.3 torch-2.4.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
from autodistill_yolov8 import YOLOv8

import os
HOME = os.getcwd()

import supervision as sv



DATA_YAML_PATH = f"{HOME}/dataset/data.yaml"

TRAINED_MODEL_PATH = f"{HOME}/runs/detect/train4/weights/last.pt"

# Load YOLOv8 model
model2 = YOLOv8(TRAINED_MODEL_PATH)

model2.train(DATA_YAML_PATH,resume=True,device=[0])
# Out:
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# New https://pypi.org/project/ultralytics/8.3.13 available  Update with 'pip install -U ultralytics'
# ...

# %%
import os
HOME = os.getcwd()
INPUT_VIDEO_PATH = f"{HOME}/vid3.mp4"
OUTPUT_VIDEO_PATH = f"{HOME}/output.mp4"
TRAINED_MODEL_PATH = f"{HOME}/runs/detect/train4/weights/best.pt"

# %%
from ultralytics import YOLO
import os

HOME = os.getcwd()

TRAINED_MODEL_PATH = f"{HOME}/runs/detect/train4/weights/best.pt"
INPUT_VIDEO_PATH = f"{HOME}/vid3.mp4"

# Load the trained model
model_inf = YOLO(TRAINED_MODEL_PATH)
# Run prediction on the input video and save the output
results_inf = model_inf.predict(INPUT_VIDEO_PATH,save=True)
# Out:
#     WARNING  stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/733) C:\Users\Prajwal\Desktop\check\vid3.mp4: 640x384 1 bowing head, 129.9ms
# video 1/1 (2/733) C:\Users\Prajwal\Desktop\check\vid3.mp4: 640x384 1 bowing head, 5.5ms
# video 1/1 (3/733) C:\Users\Prajwal\Desktop\check\vid3.mp4: 640x384 1 bowing head, 5.0ms
# video 1/1 (4/733) C:\Users\Prajwal\Desktop\check\vid3.mp4: 640x384 1 bowing head, 6.1ms
# ...

# %%
import os
HOME = os.getcwd()

print(HOME)
# Out:
# c:\Users\Prajwal\Desktop\check

# %%
from ultralytics import YOLO

# Load YOLOv8 model
target_model = YOLO("yolov8n.pt")

target_model.train(data=DATA_YAML_PATH, epochs=50, device=[0])
# Out:
# c:\Users\Prajwal\miniconda3\Lib\site-packages\ultralytics\nn\tasks.py:357: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
from ultralytics import YOLO
import os

HOME = os.getcwd()

TRAINED_MODEL_PATH = f"{HOME}/runs/detect/train3/weights/best.pt"
INPUT_VIDEO_PATH = f"{HOME}/vid4.mp4"

# Load the trained model
model_inf = YOLO(TRAINED_MODEL_PATH)
# Run prediction on the input video and save the output
results_inf = model_inf.predict(INPUT_VIDEO_PATH,save=True)
# Out:
#     WARNING  stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/1845) C:\Users\Prajwal\Desktop\check\vid4.mp4: 384x640 1 standing, 6.2ms
# video 1/1 (2/1845) C:\Users\Prajwal\Desktop\check\vid4.mp4: 384x640 1 standing, 6.6ms
# video 1/1 (3/1845) C:\Users\Prajwal\Desktop\check\vid4.mp4: 384x640 1 standing, 6.6ms
# video 1/1 (4/1845) C:\Users\Prajwal\Desktop\check\vid4.mp4: 384x640 1 standing, 6.6ms
# video 1/1 (5/1845) C:\Users\Prajwal\Desktop\check\vid4.mp4: 384x640 1 standing, 3.9ms
# ...

# %%
from ultralytics import YOLO
import os

HOME = os.getcwd()

TRAINED_MODEL_PATH = f"{HOME}/runs/detect/train3/weights/best.pt"


# Load the trained model
model = YOLO(TRAINED_MODEL_PATH)
# Run prediction on the input video and save the output

# Export command for TFLite format
model.export(format="onnx")
# Out:
# Ultralytics 8.3.27  Python-3.12.3 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i7-12700H)
# Model summary (fused): 168 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from 'c:\Users\Prajwal\Desktop\check\runs\detect\train3\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 10, 8400) (5.9 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0', 'onnxslim', 'onnxruntime'] not found, attempting AutoUpdate...
# ...
#    ---------------------------------------- 14.5/14.5 MB 4.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 140.6/140.6 kB 8.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 11.3/11.3 MB 4.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 46.0/46.0 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 86.8/86.8 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 83.2/83.2 kB 4.6 MB/s eta 0:00:00
# ...
#
# ...

# %%
from ultralytics import YOLO

# %%
import roboflow

rf = roboflow.Roboflow(api_key="FFGTQM0iZ4zPwyAUyh2j")
project = rf.workspace().project("action_detection-osimx")

#can specify weights_filename, default is "weights/best.pt"
version = project.version("1")


#example2 - directory path is "training1/weights/best.pt" for yolov8 model
version.deploy("yolov8", "C:/Users/Prajwal/Desktop/check/runs/detect/train3")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 11
#       7 version = project.version("1")
#      10 #example2 - directory path is "training1/weights/best.pt" for yolov8 model
# ---> 11 version.deploy("yolov8", "C:/Users/Prajwal/Desktop/check/runs/detect/train3")
#
# File c:\Users\Prajwal\miniconda3\Lib\site-packages\roboflow\core\version.py:547, in Version.deploy(self, model_type, model_path, filename)
#     540         raise RuntimeError(
#     541             "The ultralytics python package is required to deploy yolov10"
#     542             " models. Please install it with `pip install ultralytics`"
#     543         )
#     545     print_warn_for_wrong_dependencies_versions([("ultralytics", ">=", "8.3.0")], ask_to_continue=True)
# ...
